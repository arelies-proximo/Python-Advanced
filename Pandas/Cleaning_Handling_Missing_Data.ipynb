# %% [markdown]
# <a href="https://colab.research.google.com/github/arelies-proximo/Python-Advanced/blob/main/Pandas/Cleaning_Handling_Missing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CLEANING
#
# - Handling Missing Data
# - Converting Data to Different Type

# %% [markdown]
# Missing and Redundant Values can be present in many ways
# - NaN
# - nan
# - NA
# - np.nan
# - Null
# - None
#
# *String Representation*
#
# - 'Missing'
# - 'NA'
# - 'unknown'
# - 'Anonymous'

# %%
import numpy as np
import pandas as pd

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   5 non-null      object
#  1   last    5 non-null      object
#  2   email   5 non-null      object
#  3   age     5 non-null      object
# dtypes: object(4)
# memory usage: 352.0+ bytes

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# Using **isna()** with **any(axis=1)** to select all **rows with NaN** under an entire DataFrame

# %%
df[df.isna().any(axis=1)]
# Out:
#    first     last                email   age
# 3  Chris  Schafer                 None    36
# 4    NaN      NaN                  NaN  None
# 5   None      NaN  Anonymous@email.com  None

# %% [markdown]
# **all(axis=1)** rows with **all nan values**.

# %%
df[df.isna().all(axis=1)]
# Out:
#   first last email   age
# 4   NaN  NaN   NaN  None

# %% [markdown]
# **Dropping row with all nan**

# %%
df.drop(df[df.isna().all(axis=1)].index)
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# *4rt row have been dropped*
#
# **BUT the change is not reflected in the main df**

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.isnull()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6  False  False  False  False

# %%
df[df.isnull().any(axis=1)]
# Out:
#    first     last                email   age
# 3  Chris  Schafer                 None    36
# 4    NaN      NaN                  NaN  None
# 5   None      NaN  Anonymous@email.com  None

# %%
df[df.isnull().any(axis=0)]
# Out:
# <ipython-input-14-0beab574a96e>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.isnull().any(axis=0)]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-14-0beab574a96e> in <module>
# ----> 1 df[df.isnull().any(axis=0)]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3500         # check_bool_indexer will throw exception if Series key cannot
#    3501         # be reindexed to match DataFrame rows
# -> 3502         key = check_bool_indexer(self.index, key)
#    3503         indexer = key.nonzero()[0]
#    3504         return self._take_with_is_copy(indexer, axis=0)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2386         mask = isna(result._values)
#    2387         if mask.any():
# -> 2388             raise IndexingError(
#    2389                 "Unalignable boolean Series provided as "
#    2390                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %% [markdown]
# **CAN'T use axis=0 (columns)**
#
# *Maybe axis = n for data with multiple dimensions*

# %% [markdown]
# **isnull() and isnan() are alias**
#
# Both have same implementation.

# %%
df[df.isnull().any(axis=1)]
# Out:
#    first     last                email   age
# 3  Chris  Schafer                 None    36
# 4    NaN      NaN                  NaN  None
# 5   None      NaN  Anonymous@email.com  None

# %%
df[df.isnull().any(axis=1)]
# Out:
#    first     last                email   age
# 3  Chris  Schafer                 None    36
# 4    NaN      NaN                  NaN  None
# 5   None      NaN  Anonymous@email.com  None

# %%
#first and last names are none hence, they need to be dropped

df[df['first'].isnull()]
# Out:
#   first last                email   age
# 4   NaN  NaN                  NaN  None
# 5  None  NaN  Anonymous@email.com  None

# %%
df[df['first'].isna()]
# Out:
#   first last                email   age
# 4   NaN  NaN                  NaN  None
# 5  None  NaN  Anonymous@email.com  None

# %%
df.dropna()
  #will not affect the main df
  #will drop rows with atleast one na, and returns the undropped Rows
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# dropna() is removing all rows having at least one nan value
#
# 'NA' string, row 6 is ignored because it is a string.

# %%
#DEFAULT drop

df.dropna(axis='index', how='any')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# index - rows or columns,
#
# how = any, or all

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# *Only the 4rt will be dropped since it contains all nan values*

# %%
#Columns
df.dropna(axis='columns', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# *None of the columns have all missing values*

# %%
df.dropna(axis='columns', how='any')
  #the fourth row has nan in all columns, hence, all columns will be removed
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df[df.isna().any(axis=1)]
# Out:
#    first     last                email   age
# 3  Chris  Schafer                 None    36
# 4    NaN      NaN                  NaN  None
# 5   None      NaN  Anonymous@email.com  None

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
#REMOVING COLUMNS WHICH DO NOT HAVE FIRST NAME
df.dropna(axis='index', how='any', subset=['first'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# *Row 6 has NA as a string*
#
# 4,5 have been removed

# %%
df.dropna(axis='index', how='any',subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='any',subset=['email', 'first'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# *how=any does not make any difference for single column subset, using all will also give the same result*
#
#
# **will matter if more than one subset are present**

# %%
df.dropna(axis='index', how='all',subset=['email', 'first'])
  #both first and last must be nan
  #row 4 and row 3
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
#df.drop(df[df.isna().all(axis=1)].index, inplace=True)
  #TO DROP ROW WITH ALL NAN VALUES
  #AFFECT THE MAIN DF

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# Handling row 6, NA withing a string

# %%
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df[df.isna().all(axis=1)]
# Out:
#   first last email   age
# 4   NaN  NaN   NaN  None
# 6   NaN  NaN   NaN   NaN

# %% [markdown]
# #CASTING DATATYPES

# %%
# fillna
df.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
df.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   4 non-null      object
#  1   last    4 non-null      object
#  2   email   4 non-null      object
#  3   age     4 non-null      object
# dtypes: object(4)
# memory usage: 352.0+ bytes

# %%
df['age']
# Out:
# 0      33
# 1      55
# 2      63
# 3      36
# 4    None
# 5    None
# 6     NaN
# Name: age, dtype: object

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %% [markdown]
# object - most likely strings or mixed format (diff dtype for diff rows)

# %%
df.age.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-f4ddeff6c7d5> in <module>
# ----> 1 df.age.mean()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
#   10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10352                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10353             )
# > 10354         return self._reduce(
#   10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     664
#     665     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 666     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     667
#     668     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **If the numeric column contains missing, none valeus then it needs to be cast to float**
#
#
# **np.nan is float under the hood**

# %%
type(np.nan)
# Out:
# float

# %%
df.age.astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ee46a0702fd4> in <module>
# ----> 1 df.age.astype(int)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
df.age.astype(float)
# Out:
# 0    33.0
# 1    55.0
# 2    63.0
# 3    36.0
# 4     NaN
# 5     NaN
# 6     NaN
# Name: age, dtype: float64

# %% [markdown]
# #THREE WAYS TO HANDLE MISSING IN NUMERIC COLUMNS
#
# 1. CHANGE MISSING VALUES TO ZERO
# 2. CAST ALL VALUES TO FLOAT
#   *which will accept nan valeus, will not through error in calculating*
#
# 3. CHANGE NAN VALUES TO SOME APPROPRIATE VALUE THROUGH CALCULATION (like mean)

# %%
df.age.astype(float).sum()
# Out:
# 187.0

# %%
33+55+63+36
# Out:
# 187

# %% [markdown]
# **nan values has been taken as zero**

# %%
df[df.age.isna()]
# Out:
#   first last                email   age
# 4   NaN  NaN                  NaN  None
# 5  None  NaN  Anonymous@email.com  None
# 6   NaN  NaN                  NaN   NaN

# %%
df[df.age.isna()].age
# Out:
# 4    None
# 5    None
# 6     NaN
# Name: age, dtype: object

# %%
df.age.replace(np.nan, 0)
# Out:
# 0    33
# 1    55
# 2    63
# 3    36
# 4     0
# 5     0
# 6     0
# Name: age, dtype: object

# %% [markdown]
# *The age column with 0 age is not appropriate, best thing will be to take mean of the above ages*

# %%
df.iloc[:4, -1]
# Out:
# 0    33
# 1    55
# 2    63
# 3    36
# Name: age, dtype: object

# %%
df.iloc[:4, -1].mean()
# Out:
# 8389084.0

# %%
df.iloc[:4, -1].sum()
# Out:
# '33556336'

# %% [markdown]
# First need to convert age column to integer or float

# %%
df.age
# Out:
# 0      33
# 1      55
# 2      63
# 3      36
# 4    None
# 5    None
# 6     NaN
# Name: age, dtype: object

# %%
df.age = df.age.astype(float)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@email.com  55.0
# 2   John      Doe        JohnDoe@email.com  63.0
# 3  Chris  Schafer                     None  36.0
# 4    NaN      NaN                      NaN   NaN
# 5   None      NaN      Anonymous@email.com   NaN
# 6    NaN      NaN                      NaN   NaN

# %%
df.age.fillna(df.iloc[:4, -1].mean())
# Out:
# 0    33.00
# 1    55.00
# 2    63.00
# 3    36.00
# 4    46.75
# 5    46.75
# 6    46.75
# Name: age, dtype: float64

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@email.com  55.0
# 2   John      Doe        JohnDoe@email.com  63.0
# 3  Chris  Schafer                     None  36.0
# 4    NaN      NaN                      NaN   NaN
# 5   None      NaN      Anonymous@email.com   NaN
# 6    NaN      NaN                      NaN   NaN

# %%
df.age.fillna(df.iloc[:4, -1].mean(), inplace=True)

# %%
df
# Out:
#    first     last                    email    age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.00
# 1   Jane      Doe        JaneDoe@email.com  55.00
# 2   John      Doe        JohnDoe@email.com  63.00
# 3  Chris  Schafer                     None  36.00
# 4    NaN      NaN                      NaN  46.75
# 5   None      NaN      Anonymous@email.com  46.75
# 6    NaN      NaN                      NaN  46.75

# %%
df.age.astype(int)
# Out:
# 0    33
# 1    55
# 2    63
# 3    36
# 4    46
# 5    46
# 6    46
# Name: age, dtype: int64

# %%
df
# Out:
#    first     last                    email    age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.00
# 1   Jane      Doe        JaneDoe@email.com  55.00
# 2   John      Doe        JohnDoe@email.com  63.00
# 3  Chris  Schafer                     None  36.00
# 4    NaN      NaN                      NaN  46.75
# 5   None      NaN      Anonymous@email.com  46.75
# 6    NaN      NaN                      NaN  46.75

# %%
#removing columns which have nan for first name
df[df.first.isna()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-0ef74e2ee377> in <module>
#       1 #removing columns which have nan for first name
# ----> 2 df[df.first.isna()]
#
# AttributeError: 'function' object has no attribute 'isna'

# %%
df[df['first'].isna()]
# Out:
#   first last                email    age
# 4   NaN  NaN                  NaN  46.75
# 5  None  NaN  Anonymous@email.com  46.75
# 6   NaN  NaN                  NaN  46.75

# %%
df[df['first'].isna()].index
# Out:
# Int64Index([4, 5, 6], dtype='int64')

# %%
df.drop(df[df['first'].isna()].index)
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@email.com  55.0
# 2   John      Doe        JohnDoe@email.com  63.0
# 3  Chris  Schafer                     None  36.0

# %%
df.drop(df[df['first'].isna()].index, inplace=True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@email.com  55.0
# 2   John      Doe        JohnDoe@email.com  63.0
# 3  Chris  Schafer                     None  36.0

# %% [markdown]
# Mail is made up of last+first+@gmail.com
#
# *For company mails, made up of such combinations, 3rd option for handling (replacing)*

# %%
df[df['email'].isna()]
# Out:
#    first     last email   age
# 3  Chris  Schafer  None  36.0

# %%
df[df['email'].isna()].email
# Out:
# 3    None
# Name: email, dtype: object

# %%
df[df['email'].isna()].replace(np.nan, df['first'].astype(str)+df['last'].astype(str)+"@gmail.com")

#WRONG
# Out:
#    first     last email   age
# 3  Chris  Schafer  None  36.0

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@email.com  55.0
# 2   John      Doe        JohnDoe@email.com  63.0
# 3  Chris  Schafer                     None  36.0

# %% [markdown]
# # **TO DO**
#
# ** WAY to ADD first + last + '@gmail.com' only for row, having email as np.nan**

# %%
df[df['email'].isna()]['email'].replace(np.nan, 'MISSING')
  #how to add after np.nan such that it access only those which have email as nan
# Out:
# 3    MISSING
# Name: email, dtype: object

# %% [markdown]
# # HANDLING CSV FILE

# %%
df = pd.read_csv("survey_results_public.csv", index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df[df.isna().any(axis=1)].sample(10)
# Out:
#            Hobby OpenSource         Country         Student  \
# Respondent
# 19912         No        Yes           India  Yes, full-time
# 75423        Yes         No   United States              No
# 39860         No         No           India              No
# 47889        Yes         No   United States              No
# 43325        Yes         No     Netherlands              No
# 22206        Yes         No           India  Yes, full-time
# 99444        Yes         No  United Kingdom              No
# 60254         No         No       Australia              No
# 35868        Yes         No   United States              No
# 54039        Yes        Yes  United Kingdom              No
#
#                                     Employment  \
# Respondent
# 19912                       Employed full-time
# 75423                       Employed full-time
# 39860       Not employed, but looking for work
# 47889                       Employed full-time
# 43325                       Employed full-time
# 22206                       Employed part-time
# 99444                       Employed full-time
# 60254                       Employed full-time
# 35868                       Employed full-time
# 54039                       Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 19912                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 75423             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 39860                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 47889             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 43325       Some college/university study without earning ...
# 22206                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 99444                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 60254                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 35868       Some college/university study without earning ...
# 54039               Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 19912       Computer science, computer engineering, or sof...
# 75423       Another engineering discipline (ex. civil, ele...
# 39860       Computer science, computer engineering, or sof...
# 47889                               Mathematics or statistics
# 43325       Computer science, computer engineering, or sof...
# 22206       Computer science, computer engineering, or sof...
# 99444       Computer science, computer engineering, or sof...
# 60254                           Web development or web design
# 35868       A humanities discipline (ex. literature, histo...
# 54039       A natural science (ex. biology, chemistry, phy...
#
#                          CompanySize  \
# Respondent
# 19912             10 to 19 employees
# 75423             20 to 99 employees
# 39860                            NaN
# 47889           100 to 499 employees
# 43325           100 to 499 employees
# 22206                            NaN
# 99444        Fewer than 10 employees
# 60254             20 to 99 employees
# 35868       10,000 or more employees
# 54039           100 to 499 employees
#
#                                                       DevType  \
# Respondent
# 19912           Full-stack developer;Mobile developer;Student
# 75423       Back-end developer;Front-end developer;Full-st...
# 39860       Back-end developer;Full-stack developer;Mobile...
# 47889            Desktop or enterprise applications developer
# 43325       Back-end developer;Front-end developer;Full-st...
# 22206                                                 Student
# 99444       Back-end developer;Database administrator;Fron...
# 60254                                    Full-stack developer
# 35868       Back-end developer;Engineering manager;Front-e...
# 54039       Back-end developer;Desktop or enterprise appli...
#
#                  YearsCoding  ...                    Exercise Gender  \
# Respondent                    ...
# 19912              6-8 years  ...        3 - 4 times per week   Male
# 75423       30 or more years  ...  I don't typically exercise   Male
# 39860              3-5 years  ...                         NaN    NaN
# 47889              6-8 years  ...   Daily or almost every day   Male
# 43325              3-5 years  ...        3 - 4 times per week   Male
# 22206              3-5 years  ...                         NaN    NaN
# 99444              6-8 years  ...  I don't typically exercise    NaN
# 60254              3-5 years  ...                         NaN    NaN
# 35868            12-14 years  ...  I don't typically exercise   Male
# 54039            12-14 years  ...   Daily or almost every day   Male
#
#                    SexualOrientation  \
# Respondent
# 19912       Straight or heterosexual
# 75423       Straight or heterosexual
# 39860                            NaN
# 47889       Straight or heterosexual
# 43325       Straight or heterosexual
# 22206                            NaN
# 99444                            NaN
# 60254                            NaN
# 35868       Straight or heterosexual
# 54039       Straight or heterosexual
#
#                                              EducationParents  \
# Respondent
# 19912                               Primary/elementary school
# 75423             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 39860                                                     NaN
# 47889             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 43325       Secondary school (e.g. American high school, G...
# 22206                                                     NaN
# 99444                                                     NaN
# 60254                                                     NaN
# 35868               Other doctoral degree (Ph.D, Ed.D., etc.)
# 54039                Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                 RaceEthnicity  \
# Respondent
# 19912                                             South Asian
# 75423                            White or of European descent
# 39860                                                     NaN
# 47889       Native American, Pacific Islander, or Indigeno...
# 43325                                                     NaN
# 22206                                                     NaN
# 99444                                                     NaN
# 60254                                                     NaN
# 35868                            White or of European descent
# 54039                            White or of European descent
#
#                           Age  Dependents  MilitaryUS  \
# Respondent
# 19912       18 - 24 years old          No         NaN
# 75423       45 - 54 years old         Yes          No
# 39860                     NaN         NaN         NaN
# 47889       35 - 44 years old         Yes          No
# 43325       18 - 24 years old          No         NaN
# 22206                     NaN         NaN         NaN
# 99444                     NaN         NaN         NaN
# 60254                     NaN         NaN         NaN
# 35868       35 - 44 years old         Yes          No
# 54039       25 - 34 years old         Yes         NaN
#
#                                    SurveyTooLong                  SurveyEasy
# Respondent
# 19912       The survey was an appropriate length  Neither easy nor difficult
# 75423                    The survey was too long               Somewhat easy
# 39860                                        NaN                         NaN
# 47889       The survey was an appropriate length                   Very easy
# 43325       The survey was an appropriate length  Neither easy nor difficult
# 22206                                        NaN                         NaN
# 99444                                        NaN                         NaN
# 60254                                        NaN                         NaN
# 35868       The survey was an appropriate length                   Very easy
# 54039                    The survey was too long  Neither easy nor difficult
#
# [10 rows x 128 columns]

# %%
df[df.isna().any(axis=1)].count()
# Out:
# Hobby            98849
# OpenSource       98849
# Country          98437
# Student          94895
# Employment       95315
#                  ...
# Age              64568
# Dependents       62590
# MilitaryUS       15775
# SurveyTooLong    65935
# SurveyEasy       65873
# Length: 128, dtype: int64

# %%
df['Hobby'].str.findall('Missing')
# Out:
# Respondent
# 1         []
# 3         []
# 4         []
# 5         []
# 7         []
#           ..
# 101513    []
# 101531    []
# 101541    []
# 101544    []
# 101548    []
# Name: Hobby, Length: 98855, dtype: object

# %% [markdown]
# Before reading the data into dataframe, values can be passed in pd.read_csv to handle nan values.

# %%
na_vals = ['NA', 'Missing', None]

#passing to parameter na_values
df = pd.read_csv("survey_results_public.csv", index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # QUESTION:
#
# **Average coding Experience in Year**

# %%
df.head(10)
# Out:
#            Hobby OpenSource         Country         Student  \
# Respondent
# 1            Yes         No           Kenya              No
# 3            Yes        Yes  United Kingdom              No
# 4            Yes        Yes   United States              No
# 5             No         No   United States              No
# 7            Yes         No    South Africa  Yes, part-time
# 8            Yes         No  United Kingdom              No
# 9            Yes        Yes   United States              No
# 10           Yes        Yes         Nigeria              No
# 11           Yes        Yes   United States              No
# 16            No        Yes           India              No
#
#                     Employment  \
# Respondent
# 1           Employed part-time
# 3           Employed full-time
# 4           Employed full-time
# 5           Employed full-time
# 7           Employed full-time
# 8           Employed full-time
# 9           Employed full-time
# 10          Employed full-time
# 11          Employed full-time
# 16          Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                            Associate degree
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7           Some college/university study without earning ...
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
# 10                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11          Some college/university study without earning ...
# 16                   Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                   Mathematics or statistics
# 3           A natural science (ex. biology, chemistry, phy...
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 7           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 10          Computer science, computer engineering, or sof...
# 11          Fine arts or performing arts (ex. graphic desi...
# 16          Computer science, computer engineering, or sof...
#
#                          CompanySize  \
# Respondent
# 1                 20 to 99 employees
# 3           10,000 or more employees
# 4                 20 to 99 employees
# 5               100 to 499 employees
# 7           10,000 or more employees
# 8                 10 to 19 employees
# 9           10,000 or more employees
# 10                10 to 19 employees
# 11              100 to 499 employees
# 16              500 to 999 employees
#
#                                                       DevType  \
# Respondent
# 1                                        Full-stack developer
# 3           Database administrator;DevOps specialist;Full-...
# 4                    Engineering manager;Full-stack developer
# 5                                        Full-stack developer
# 7           Data or business analyst;Desktop or enterprise...
# 8           Back-end developer;Database administrator;Fron...
# 9           Back-end developer;Front-end developer;Full-st...
# 10          Designer;Front-end developer;QA or test developer
# 11          Back-end developer;C-suite executive (CEO, CTO...
# 16                                                   Designer
#
#                  YearsCoding  ...                    Exercise  Gender  \
# Respondent                    ...
# 1                  3-5 years  ...        3 - 4 times per week    Male
# 3           30 or more years  ...   Daily or almost every day    Male
# 4                24-26 years  ...                         NaN     NaN
# 5                18-20 years  ...  I don't typically exercise    Male
# 7                  6-8 years  ...        3 - 4 times per week    Male
# 8                  6-8 years  ...        1 - 2 times per week    Male
# 9                 9-11 years  ...  I don't typically exercise    Male
# 10                 0-2 years  ...        1 - 2 times per week  Female
# 11          30 or more years  ...  I don't typically exercise    Male
# 16                 0-2 years  ...                         NaN     NaN
#
#                    SexualOrientation  \
# Respondent
# 1           Straight or heterosexual
# 3           Straight or heterosexual
# 4                                NaN
# 5           Straight or heterosexual
# 7           Straight or heterosexual
# 8           Straight or heterosexual
# 9           Straight or heterosexual
# 10                               NaN
# 11          Straight or heterosexual
# 16                               NaN
#
#                                              EducationParents  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                                         NaN
# 5           Some college/university study without earning ...
# 7           Some college/university study without earning ...
# 8           Secondary school (e.g. American high school, G...
# 9                 Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 10                                  Primary/elementary school
# 11          Some college/university study without earning ...
# 16                                                        NaN
#
#                            RaceEthnicity                Age  Dependents  \
# Respondent
# 1            Black or of African descent  25 - 34 years old         Yes
# 3           White or of European descent  35 - 44 years old         Yes
# 4                                    NaN                NaN         NaN
# 5           White or of European descent  35 - 44 years old          No
# 7           White or of European descent  18 - 24 years old         Yes
# 8           White or of European descent  18 - 24 years old          No
# 9           White or of European descent  18 - 24 years old          No
# 10           Black or of African descent  25 - 34 years old          No
# 11          White or of European descent  35 - 44 years old         Yes
# 16                                   NaN                NaN         NaN
#
#             MilitaryUS                         SurveyTooLong  \
# Respondent
# 1                  NaN  The survey was an appropriate length
# 3                  NaN  The survey was an appropriate length
# 4                  NaN                                   NaN
# 5                   No  The survey was an appropriate length
# 7                  NaN  The survey was an appropriate length
# 8                  NaN  The survey was an appropriate length
# 9                   No  The survey was an appropriate length
# 10                 NaN               The survey was too long
# 11                  No  The survey was an appropriate length
# 16                 NaN                                   NaN
#
#                     SurveyEasy
# Respondent
# 1                    Very easy
# 3                Somewhat easy
# 4                          NaN
# 5                Somewhat easy
# 7                Somewhat easy
# 8                Somewhat easy
# 9                Somewhat easy
# 10          Somewhat difficult
# 11                   Very easy
# 16                         NaN
#
# [10 rows x 128 columns]

# %%
df.columns
# Out:
# Index(['Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        'YearsCoding',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=128)

# %%
list(df.columns)
# Out:
# ['Hobby',
#  'OpenSource',
#  'Country',
#  'Student',
#  'Employment',
#  'FormalEducation',
#  'UndergradMajor',
#  'CompanySize',
#  'DevType',
#  'YearsCoding',
#  'YearsCodingProf',
#  'JobSatisfaction',
#  'CareerSatisfaction',
#  'HopeFiveYears',
#  'JobSearchStatus',
#  'LastNewJob',
#  'AssessJob1',
#  'AssessJob2',
#  'AssessJob3',
#  'AssessJob4',
#  'AssessJob5',
#  'AssessJob6',
#  'AssessJob7',
#  'AssessJob8',
#  'AssessJob9',
#  'AssessJob10',
#  'AssessBenefits1',
#  'AssessBenefits2',
#  'AssessBenefits3',
#  'AssessBenefits4',
#  'AssessBenefits5',
#  'AssessBenefits6',
#  'AssessBenefits7',
#  'AssessBenefits8',
#  'AssessBenefits9',
#  'AssessBenefits10',
#  'AssessBenefits11',
#  'JobContactPriorities1',
#  'JobContactPriorities2',
#  'JobContactPriorities3',
#  'JobContactPriorities4',
#  'JobContactPriorities5',
#  'JobEmailPriorities1',
#  'JobEmailPriorities2',
#  'JobEmailPriorities3',
#  'JobEmailPriorities4',
#  'JobEmailPriorities5',
#  'JobEmailPriorities6',
#  'JobEmailPriorities7',
#  'UpdateCV',
#  'Currency',
#  'Salary',
#  'SalaryType',
#  'ConvertedSalary',
#  'CurrencySymbol',
#  'CommunicationTools',
#  'TimeFullyProductive',
#  'EducationTypes',
#  'SelfTaughtTypes',
#  'TimeAfterBootcamp',
#  'HackathonReasons',
#  'AgreeDisagree1',
#  'AgreeDisagree2',
#  'AgreeDisagree3',
#  'LanguageWorkedWith',
#  'LanguageDesireNextYear',
#  'DatabaseWorkedWith',
#  'DatabaseDesireNextYear',
#  'PlatformWorkedWith',
#  'PlatformDesireNextYear',
#  'FrameworkWorkedWith',
#  'FrameworkDesireNextYear',
#  'IDE',
#  'OperatingSystem',
#  'NumberMonitors',
#  'Methodology',
#  'VersionControl',
#  'CheckInCode',
#  'AdBlocker',
#  'AdBlockerDisable',
#  'AdBlockerReasons',
#  'AdsAgreeDisagree1',
#  'AdsAgreeDisagree2',
#  'AdsAgreeDisagree3',
#  'AdsActions',
#  'AdsPriorities1',
#  'AdsPriorities2',
#  'AdsPriorities3',
#  'AdsPriorities4',
#  'AdsPriorities5',
#  'AdsPriorities6',
#  'AdsPriorities7',
#  'AIDangerous',
#  'AIInteresting',
#  'AIResponsible',
#  'AIFuture',
#  'EthicsChoice',
#  'EthicsReport',
#  'EthicsResponsible',
#  'EthicalImplications',
#  'StackOverflowRecommend',
#  'StackOverflowVisit',
#  'StackOverflowHasAccount',
#  'StackOverflowParticipate',
#  'StackOverflowJobs',
#  'StackOverflowDevStory',
#  'StackOverflowJobsRecommend',
#  'StackOverflowConsiderMember',
#  'HypotheticalTools1',
#  'HypotheticalTools2',
#  'HypotheticalTools3',
#  'HypotheticalTools4',
#  'HypotheticalTools5',
#  'WakeTime',
#  'HoursComputer',
#  'HoursOutside',
#  'SkipMeals',
#  'ErgonomicDevices',
#  'Exercise',
#  'Gender',
#  'SexualOrientation',
#  'EducationParents',
#  'RaceEthnicity',
#  'Age',
#  'Dependents',
#  'MilitaryUS',
#  'SurveyTooLong',
#  'SurveyEasy']

# %%
df['YearsCoding']
# Out:
# Respondent
# 1                3-5 years
# 3         30 or more years
# 4              24-26 years
# 5              18-20 years
# 7                6-8 years
#                 ...
# 101513                 NaN
# 101531           0-2 years
# 101541                 NaN
# 101544                 NaN
# 101548                 NaN
# Name: YearsCoding, Length: 98855, dtype: object

# %%
df['YearsCoding'] = df['YearsCoding'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-c1394c6d60a1> in <module>
# ----> 1 df['YearsCoding'] = df['YearsCoding'].astype(float)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1199     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#    1203     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '3-5 years'

# %%
df['YearsCoding'].replace('years', " ", inplace=True)
  #THIS IS NOT WORKING
  #Will replace only if the whole cell value is years, NOT CONTAINS year

# %%
df['YearsCoding']
# Out:
# Respondent
# 1                3-5 years
# 3         30 or more years
# 4              24-26 years
# 5              18-20 years
# 7                6-8 years
#                 ...
# 101513                 nan
# 101531           0-2 years
# 101541                 nan
# 101544                 nan
# 101548                 nan
# Name: YearsCoding, Length: 98855, dtype: object

# %%
df['YearsCoding'].replace('3-5 years', '', inplace=True)

# %%
df['YearsCoding']
# Out:
# Respondent
# 1
# 3         30 or more years
# 4              24-26 years
# 5              18-20 years
# 7                6-8 years
#                 ...
# 101513                 nan
# 101531           0-2 years
# 101541                 nan
# 101544                 nan
# 101548                 nan
# Name: YearsCoding, Length: 98855, dtype: object

# %%
#bringing the data back to original format
df['YearsCoding'].replace(" ",'3-5 years', inplace=True)

# %%
df['YearsCoding']
# Out:
# Respondent
# 1                3-5 years
# 3         30 or more years
# 4              24-26 years
# 5              18-20 years
# 7                6-8 years
#                 ...
# 101513                 nan
# 101531           0-2 years
# 101541                 nan
# 101544                 nan
# 101548                 nan
# Name: YearsCoding, Length: 98855, dtype: object

# %%
df['YearsCoding'].unique()
# Out:
# array(['3-5 years', '30 or more years', '24-26 years', '18-20 years',
#        '6-8 years', '9-11 years', '0-2 years', '15-17 years',
#        '12-14 years', '21-23 years', '27-29 years', 'nan'], dtype=object)

# %%
df['YearsCoding']= df['YearsCoding'].map({'3-5 years':4, '30 or more years':35, '24-26 years':25, '18-20 years':19, '6-8 years':7, '9-11 years':10, '0-2 years':1, 
                       '15-17 years':16, '12-14 years':13, '21-23 years':22, '27-29 years':28})

# %%
df['YearsCoding']
# Out:
# Respondent
# 1          4.0
# 3         35.0
# 4         25.0
# 5         19.0
# 7          7.0
#           ...
# 101513     NaN
# 101531     1.0
# 101541     NaN
# 101544     NaN
# 101548     NaN
# Name: YearsCoding, Length: 98855, dtype: float64

# %%
df['YearsCoding'].astype(float)
# Out:
# Respondent
# 1          4.0
# 3         35.0
# 4         25.0
# 5         19.0
# 7          7.0
#           ...
# 101513     NaN
# 101531     1.0
# 101541     NaN
# 101544     NaN
# 101548     NaN
# Name: YearsCoding, Length: 98855, dtype: float64

# %%
df['YearsCoding'].mean()
# Out:
# 9.784685884797783

# %%
df['YearsCoding'].mean().round(2)
# Out:
# 9.78

# %%
df['YearsCoding'].median()
# Out:
# 7.0

# %%
df['YearsCoding'].describe()
# Out:
# count    93835.000000
# mean         9.784686
# std          7.953802
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         13.000000
# max         35.000000
# Name: YearsCoding, dtype: float64
